# %% [markdown]
# <a href="https://colab.research.google.com/github/chamorrosandra214-rgb/BOTELLAS-DESCARTADAS/blob/main/FABRICA%20DE%20BOTELLAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import simpy
import random

# Parámetros del sistema
TIEMPO_MOLDEO = 30        # segundos (media)
TIEMPO_ENFRIAMIENTO = 60  # segundos (constante)
TIEMPO_INSPECCION = 45    # segundos (media)
TAMANO_LOTE_EMPAQUE = 100 # botellas por lote
NUM_MAQUINAS_MOLDEO = 2
NUM_INSPECTORES = 1

# Proceso de producción de una botella
def producir_botella(env, id_botella, moldeo, inspeccion, empaque):
    # Moldeo
    with moldeo.request() as req:
        yield req
        tiempo = random.normalvariate(TIEMPO_MOLDEO, 5)
        yield env.timeout(tiempo)
        print(f"Botella {id_botella} moldeada en {env.now:.1f}")

    # Enfriamiento
    yield env.timeout(TIEMPO_ENFRIAMIENTO)
    print(f"Botella {id_botella} enfriada en {env.now:.1f}")

    # Inspección
    with inspeccion.request() as req:
        yield req
        tiempo = random.expovariate(1.0/TIEMPO_INSPECCION)
        yield env.timeout(tiempo)
        print(f"Botella {id_botella} inspeccionada en {env.now:.1f}")

    # Empaque (se acumulan hasta formar un lote)
    empaque.append(id_botella)
    if len(empaque) >= TAMANO_LOTE_EMPAQUE:
        print(f"Lote de {TAMANO_LOTE_EMPAQUE} botellas empacado en {env.now:.1f}")
        empaque.clear()

# Generador de llegadas de botellas
def llegada_botellas(env, moldeo, inspeccion, empaque):
    id_botella = 0
    while True:
        yield env.timeout(random.expovariate(1/20))  # llegada cada ~20 seg
        id_botella += 1
        env.process(producir_botella(env, id_botella, moldeo, inspeccion, empaque))

# Configuración del entorno
env = simpy.Environment()
moldeo = simpy.Resource(env, NUM_MAQUINAS_MOLDEO)
inspeccion = simpy.Resource(env, NUM_INSPECTORES)
empaque = []

# Iniciar simulación
env.process(llegada_botellas(env, moldeo, inspeccion, empaque))
env.run(until=500)  # simular 500 segundos
# Out:
# Botella 1 moldeada en 40.8
# Botella 2 moldeada en 52.1
# Botella 3 moldeada en 72.0
# Botella 4 moldeada en 76.0
# Botella 1 enfriada en 100.8
# Botella 5 moldeada en 101.4
# Botella 1 inspeccionada en 108.7
# Botella 2 enfriada en 112.1
# Botella 3 enfriada en 132.0
# Botella 4 enfriada en 136.0
# Botella 6 moldeada en 145.0
# Botella 5 enfriada en 161.4
# Botella 2 inspeccionada en 164.1
# Botella 7 moldeada en 171.0
# Botella 3 inspeccionada en 171.7
# Botella 6 enfriada en 205.0
# Botella 4 inspeccionada en 230.6
# Botella 7 enfriada en 231.0
# Botella 8 moldeada en 237.0
# Botella 5 inspeccionada en 241.4
# Botella 9 moldeada en 253.9
# Botella 10 moldeada en 269.0
# Botella 8 enfriada en 297.0
# Botella 9 enfriada en 313.9
# Botella 6 inspeccionada en 315.1
# Botella 11 moldeada en 328.5
# Botella 10 enfriada en 329.0
# Botella 12 moldeada en 351.0
# Botella 13 moldeada en 355.7
# Botella 14 moldeada en 377.7
# Botella 15 moldeada en 386.1
# Botella 11 enfriada en 388.5
# Botella 12 enfriada en 411.0
# Botella 16 moldeada en 411.7
# Botella 13 enfriada en 415.7
# Botella 17 moldeada en 424.7
# Botella 14 enfriada en 437.7
# Botella 18 moldeada en 438.6
# Botella 15 enfriada en 446.1
# Botella 19 moldeada en 453.1
# Botella 20 moldeada en 468.1
# Botella 16 enfriada en 471.7
# Botella 7 inspeccionada en 479.4
# Botella 21 moldeada en 482.1
# Botella 17 enfriada en 484.7
# Botella 22 moldeada en 498.0
# Botella 18 enfriada en 498.6
